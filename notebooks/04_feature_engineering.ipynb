# %%
import sys
from pathlib import Path

# add project root to Python path
project_root = Path().resolve().parents[0]
sys.path.append(str(project_root))

# %%
X, y, df_clean = build_X_y("../data/insurance.csv", include_bmi_smoker=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 X, y, df_clean = build_X_y("../data/insurance.csv", include_bmi_smoker=True)
#
# NameError: name 'build_X_y' is not defined

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 X.head()
#
# NameError: name 'X' is not defined

# %%
X.shape
# Out:
# (1337, 8)

# %% [markdown]
# ## Feature Engineering Summary
# - Target variable: log-transformed insurance charges
# - Core predictors: age, BMI, number of children, smoking status
# - Region encoded using one-hot encoding
# - BMI × smoker

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.duplicated().sum()
#
# NameError: name 'df' is not defined
